# %%
import torchvision
from torchvision import transforms
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
# Out:
# Running cells with 'e:\Python\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'e:/Python/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
transform = transforms.Compose([
    transforms.Resize(224),  # Resize the image so that the smaller dimension is 224 pixels
    transforms.CenterCrop(224),  # Center-crop the image to 224x224
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize the image
])

# %%
# Download the Flowers-102 dataset
torchvision.datasets.Flowers102(root='./datasetFlower', download=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to dataset/flowers-102/102flowers.tgz
# 100%|████████████████████████████████████████████████████████████████| 344862509/344862509 [02:40<00:00, 2147017.00it/s]
# Extracting dataset/flowers-102/102flowers.tgz to dataset/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to dataset/flowers-102/imagelabels.mat
# 100%|█████████████████████████████████████████████████████████████████████████████| 502/502 [00:00<00:00, 339987.18it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to dataset/flowers-102/setid.mat
# 100%|████████████████████████████████████████████████████████████████████████| 14989/14989 [00:00<00:00, 5422496.35it/s]

# %%
dataset = ImageFolder(root='/app/src/datasetFlower/flowers-102',transform=transform)

# Create a subplot for displaying the images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))

# Show the first 10 images
for i in range(10):
    img, label = dataset[i]
    ax = axes[i // 5, i % 5]
    ax.set_title(f"Class: {label}")
    ax.imshow(img.permute(1, 2, 0))  # Convert (C, H, W) to (H, W, C) for displaying in matplotlib
    ax.axis('off')

plt.tight_layout()
plt.show()
